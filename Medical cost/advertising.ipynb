# %%
import numpy as np 
import pandas as pd

# %%
df_adv_data = pd.read_csv("advertising.csv")
df_adv_data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
df_adv_data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
df_adv_data.size
# Out:
# 800

# %%
df_adv_data.shape
# Out:
# (200, 4)

# %%
df_adv_data.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
X_feature = df_adv_data[['Newspaper','Radio','TV']]
X_feature.head()
# Out:
#    Newspaper  Radio     TV
# 0       69.2   37.8  230.1
# 1       45.1   39.3   44.5
# 2       69.3   45.9   17.2
# 3       58.5   41.3  151.5
# 4       58.4   10.8  180.8

# %%
Y_target = df_adv_data[['Sales']]
Y_target.head()
# Out:
#    Sales
# 0   22.1
# 1   10.4
# 2   12.0
# 3   16.5
# 4   17.9

# %%
X_feature.shape
# Out:
# (200, 3)

# %%
Y_target.shape
# Out:
# (200, 1)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X_feature, Y_target, random_state=1)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (150, 3)
# (150, 1)
# (50, 3)
# (50, 1)

# %%
from sklearn.linear_model import LinearRegression
linreg = LinearRegression()
linreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
print(linreg.intercept_)
print(linreg.coef_)
# Out:
# [4.63380855]
# [[0.00078783 0.10218027 0.05483762]]

# %%
y_pred = linreg.predict(x_test)
y_pred
# Out:
# array([[21.29142142],
#        [18.04194205],
#        [10.03065109],
#        [21.04818991],
#        [20.75167113],
#        [24.52948332],
#        [16.85936471],
#        [15.69800653],
#        [10.17237239],
#        [18.90266535],
#        [15.82750789],
#        [10.53768469],
#        [18.86292327],
#        [15.57969067],
#        [17.89853384],
#        [15.35974564],
#        [13.76329903],
#        [21.00074026],
#        [10.03000895],
#        [19.20973979],
#        [11.12327234],
#        [12.18140998],
#        [ 8.67037889],
#        [11.96248005],
#        [12.63332284],
#        [16.83484748],
#        [ 9.75317608],
#        [21.06453498],
#        [18.075131  ],
#        [19.52477289],
#        [22.04440958],
#        [17.90745151],
#        [16.48534479],
#        [14.79190923],
#        [21.3573104 ],
#        [16.9364024 ],
#        [17.18742868],
#        [12.33688324],
#        [21.02974736],
#        [ 7.77584247],
#        [ 5.413222  ],
#        [ 9.64006117],
#        [ 6.91408859],
#        [19.22413789],
#        [ 7.93800502],
#        [15.16854596],
#        [13.73132724],
#        [21.01419263],
#        [20.49929224],
#        [20.57792216]])

# %%
from sklearn.metrics import mean_squared_error,r2_score
import numpy as np

# %%
print(np.sqrt(metrics.mean_squared_error(y_test,y_pred)))
# Out:
# 1.5096109295725841

# %%
score=r2_score(y_test,y_pred)
print('R2-score is ',score)
print('Mean_sqrd_error is==',mean_squared_error(y_test,y_pred))
print('Root_mean_squared error of is==',np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# R2-score is  0.904891724136168
# Mean_sqrd_error is== 2.2789251586850017
# Root_mean_squared error of is== 1.5096109295725841
